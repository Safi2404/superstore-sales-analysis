# %%
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"C:\Users\safih\train.csv", encoding = 'latin-1')
print(df.shape)
print(df.columns)
print(df.head())
print(df.isnull().sum())
# converting dates to proper format
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)
# adding some useful columns
df['Shipping Days'] = (df['Ship Date'] - df['Order Date']).dt.days
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
print("done")
region_sales = df.groupby('Region')['Sales'].sum()
region_sales.plot(kind='bar')
plt.title('Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')
plt.title('Sales by Category')
plt.ylabel('Sales')
plt.show()
sub_sales = df.groupby('Sub-Category')['Sales'].sum().sort_values()

sub_sales.plot(kind='barh')
plt.title('Sales by Sub-Category')
plt.xlabel('Sales')
plt.show()
monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot(kind='line', marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()
segment_sales = df.groupby('Segment')['Sales'].sum()

segment_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales by Segment')
plt.ylabel('')
plt.show()
top_customers = df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_customers.plot(kind='bar')
plt.title('Top 10 Customers')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()
plt.hist(df['Shipping Days'], bins=10)
plt.title('Shipping Days Distribution')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()
print("Total Sales:", df['Sales'].sum().round(2))
print("Average Order Value:", df['Sales'].mean().round(2))
print("Total Orders:", df['Order ID'].nunique())
print("Total Customers:", df['Customer Name'].nunique())
print("Avg Shipping Days:", df['Shipping Days'].mean().round(1))
print("Best Region:", df.groupby('Region')['Sales'].sum().idxmax())
print("Best Category:", df.groupby('Category')['Sales'].sum().idxmax())
# Out:
# (9800, 18)
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# ...

# %% [markdown]
# # Superstore Sales Analysis
#
# A data analysis project on US Superstore sales data using Python.
#
# ## About the Dataset
# - 9,800 sales records
# - 18 columns including Order Date, Region, Category, Segment and Sales
# - Source: Kaggle
#
# ## Tools Used
# - Python
# - Pandas
# - Matplotlib
# - Seaborn
# - VS Code (Jupyter Notebook)
#
# ## What I Analyzed
# - Sales performance across different regions
# - Sales breakdown by product category and sub-category
# - Monthly sales trends over time
# - Customer segment contribution to total revenue
# - Top 10 customers by sales
# - Shipping days distribution
#
# ## Key Findings
# - **Total Sales:** $2,261,536
# - **Total Orders:** 4,922
# - **Total Customers:** 793
# - **Average Order Value:** $230.77
# - **Average Shipping Days:** 4 days
# - **Best Performing Region:** West
# - **Top Category:** Technology
# - **Top Sub-Category:** Phones
# - **Biggest Customer Segment:** Consumer
#
# ## How to Run
# 1. Clone this repository
# 2. Place `train.csv` in the project folder
# 3. Open `Store_sales.ipynb` in VS Code
# 4. Run all cells from top to bottom
#
# ## Project Structure
# ```
# superstore-analysis/
# │
# ├── Store_sales.ipynb   # main notebook
# ├── train.csv           # dataset
# └── README.md           # project info
# ```
